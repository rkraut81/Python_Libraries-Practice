# %% [markdown]
# # Concatenate DataFrames

# %% [markdown]
# RESTAURANT DATA FRAMES COMBINING AND MERGING

# %%
import pandas as pd
import numpy as np

# %%
#Userinfo
usercuisine=pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\usercuisine.csv')
payment= pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\userpayment.csv')
profile=pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\userprofile.csv')

# restaurant info
rest_accepts = pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\chefmozaccepts.csv')
rest_cuisine = pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\chefmozcuisine.csv')
rest_hours   = pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\chefmozhours4.csv')
rest_parking = pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\chefmozparking.csv')

# Loc and rating info
geo_loc = pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\geoplaces2.csv')
rating_final = pd.read_csv(r'C:\Users\Aarav\Desktop\end to end data sets\restaurant-data-with-consumer-ratings\rating_final.csv')

# %%
usercuisine.head()
# Out:
#   userID          Rcuisine
# 0  U1001          American
# 1  U1002           Mexican
# 2  U1003           Mexican
# 3  U1004            Bakery
# 4  U1004  Breakfast-Brunch

# %%
pd.set_option('display.max_columns',25)
geo_loc.head()
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                              name                                 address  \
# 0                 Kiku Cuernavaca                              Revolucion
# 1                 puesto de tacos  esquina santos degollado y leon guzman
# 2      El Rinc�n de San Francisco                         Universidad 169
# 3  little pizza Emilio Portes Gil                 calle emilio portes gil
# ...

# %%
# Combining all data frames into one

rest_data= pd.concat([usercuisine,payment,profile,rest_accepts,rest_cuisine,rest_hours,rest_parking,geo_loc,rating_final],ignore_index=True)

pd.set_option('display.max_columns',100)
rest_data.head(10)
# Out:
#   Rambience          Rcuisine Rpayment Upayment accessibility activity  \
# 0       NaN          American      NaN      NaN           NaN      NaN
# 1       NaN           Mexican      NaN      NaN           NaN      NaN
# 2       NaN           Mexican      NaN      NaN           NaN      NaN
# 3       NaN            Bakery      NaN      NaN           NaN      NaN
# 4       NaN  Breakfast-Brunch      NaN      NaN           NaN      NaN
# 5       NaN          Japanese      NaN      NaN           NaN      NaN
# 6       NaN      Contemporary      NaN      NaN           NaN      NaN
# 7       NaN           Mexican      NaN      NaN           NaN      NaN
# 8       NaN            Bagels      NaN      NaN           NaN      NaN
# 9       NaN  Cafe-Coffee_Shop      NaN      NaN           NaN      NaN
#
#   address alcohol ambience area  birth_year budget city color country days  \
# 0     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN  NaN
# ...

# %%
frames = [usercuisine,payment,profile,rest_accepts,rest_cuisine,rest_hours,rest_parking,geo_loc,rating_final]
rest_keys = pd.concat(frames, keys = ['usr_cu','pay','pro','rst_accpt','rst_cu','rst_hrs','rst_prkg','glc','rating_fnl'])

# %%
pd.set_option('display.max_columns',50)
rest_keys.head()
# Out:
#          Rambience          Rcuisine Rpayment Upayment accessibility activity  \
# usr_cu 0       NaN          American      NaN      NaN           NaN      NaN
#        1       NaN           Mexican      NaN      NaN           NaN      NaN
#        2       NaN           Mexican      NaN      NaN           NaN      NaN
#        3       NaN            Bakery      NaN      NaN           NaN      NaN
#        4       NaN  Breakfast-Brunch      NaN      NaN           NaN      NaN
#
#          address alcohol ambience area  birth_year budget city color country  \
# usr_cu 0     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN
#        1     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN
#        2     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN
#        3     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN
#        4     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN
#
# ...

# %%
rest_keys.loc['pay'].head()
# Out:
#   Rambience Rcuisine Rpayment          Upayment accessibility activity  \
# 0       NaN      NaN      NaN              cash           NaN      NaN
# 1       NaN      NaN      NaN              cash           NaN      NaN
# 2       NaN      NaN      NaN              cash           NaN      NaN
# 3       NaN      NaN      NaN              cash           NaN      NaN
# 4       NaN      NaN      NaN  bank_debit_cards           NaN      NaN
#
#   address alcohol ambience area  birth_year budget city color country days  \
# 0     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN  NaN
# 1     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN  NaN
# 2     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN  NaN
# 3     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN  NaN
# 4     NaN     NaN      NaN  NaN         NaN    NaN  NaN   NaN     NaN  NaN
#
#   dress_code dress_preference drink_level  fax  food_rating franchise  height  \
# ...

# %%
rest_dict_keys={'usr_cu':usercuisine,
               'pay':payment,
               'pro':profile,
               'rst_accpt':rest_accepts,
                'rst_cu':rest_cuisine,
                'rst_hrs':rest_hours,
                'rst_prkg':rest_parking,
                'glc':geo_loc,
                'rating_fnl':rating_final}

# %%
rest_keys_frame=pd.concat(rest_dict_keys)
rest_keys_frame.head()
# Out:
#       Rambience Rcuisine Rpayment Upayment     accessibility activity  \
# glc 0  familiar      NaN      NaN      NaN  no_accessibility      NaN
#     1  familiar      NaN      NaN      NaN        completely      NaN
#     2  familiar      NaN      NaN      NaN         partially      NaN
#     3  familiar      NaN      NaN      NaN        completely      NaN
#     4  familiar      NaN      NaN      NaN        completely      NaN
#
#                                       address            alcohol ambience  \
# glc 0                              Revolucion  No_Alcohol_Served      NaN
#     1  esquina santos degollado y leon guzman  No_Alcohol_Served      NaN
#     2                         Universidad 169          Wine-Beer      NaN
#     3                 calle emilio portes gil  No_Alcohol_Served      NaN
#     4                  lic. Emilio portes gil  No_Alcohol_Served      NaN
#
#          area  birth_year budget             city color country days  \
# ...

# %%
rest_col = pd.concat([usercuisine,payment,profile],axis=1)

# %%
rest_col.head()
# Out:
#   userID          Rcuisine userID          Upayment userID   latitude  \
# 0  U1001          American  U1001              cash  U1001  22.139997
# 1  U1002           Mexican  U1002              cash  U1002  22.150087
# 2  U1003           Mexican  U1003              cash  U1003  22.119847
# 3  U1004            Bakery  U1004              cash  U1004  18.867000
# 4  U1004  Breakfast-Brunch  U1004  bank_debit_cards  U1005  22.183477
#
#     longitude smoker     drink_level dress_preference ambience transport  \
# 0 -100.978803  false      abstemious         informal   family   on foot
# 1 -100.983325  false      abstemious         informal   family    public
# 2 -100.946527  false  social drinker           formal   family    public
# 3  -99.183000  false      abstemious         informal   family    public
# 4 -100.959891  false      abstemious    no preference   family    public
#
#   marital_status        hijos  birth_year    interest          personality  \
# ...

# %% [markdown]
# # MERGING DATA DRAMES

# %%
rest_merge = pd.merge(usercuisine, payment , on = 'userID')

# %%
rest_merge1 = pd.merge(usercuisine, payment , on = 'userID')

# %%
rest_merge.head()
# Out:
#   userID  Rcuisine          Upayment
# 0  U1001  American              cash
# 1  U1002   Mexican              cash
# 2  U1003   Mexican              cash
# 3  U1004    Bakery              cash
# 4  U1004    Bakery  bank_debit_cards

# %%
# full outer join

rest_full_outer_join=pd.merge(rest_accepts,rest_cuisine, on='placeID', how='outer')

# %%
rest_full_outer_join.head()
# Out:
#    placeID             Rpayment Rcuisine
# 0   135110                 cash  Spanish
# 1   135110                 VISA  Spanish
# 2   135110  MasterCard-Eurocard  Spanish
# 3   135110     American_Express  Spanish
# 4   135110     bank_debit_cards  Spanish

# %%
rest_inner_join = pd.merge(rest_accepts, rest_cuisine, on='placeID', how='inner')

# %%
rest_inner_join.head()
# Out:
#    placeID             Rpayment Rcuisine
# 0   135110                 cash  Spanish
# 1   135110                 VISA  Spanish
# 2   135110  MasterCard-Eurocard  Spanish
# 3   135110     American_Express  Spanish
# 4   135110     bank_debit_cards  Spanish

# %%
rest_right_join=pd.merge(rest_accepts,rest_cuisine,on = 'placeID', how='right')

# %%
rest_right_join.head()
# Out:
#    placeID             Rpayment Rcuisine
# 0   135110                 cash  Spanish
# 1   135110                 VISA  Spanish
# 2   135110  MasterCard-Eurocard  Spanish
# 3   135110     American_Express  Spanish
# 4   135110     bank_debit_cards  Spanish

# %%
rest_left_join=pd.merge(rest_accepts,rest_cuisine,on = 'placeID', how='left')

# %%
rest_left_join.head()
# Out:
#    placeID             Rpayment Rcuisine
# 0   135110                 cash  Spanish
# 1   135110                 VISA  Spanish
# 2   135110  MasterCard-Eurocard  Spanish
# 3   135110     American_Express  Spanish
# 4   135110     bank_debit_cards  Spanish

# %% [markdown]
# #JOINING ON INDEX

# %%
rest_index_df = pd.merge(rest_accepts, rest_cuisine, right_index=True, left_index=True)

# %%
rest_index_df.head()
# Out:
#    placeID_x             Rpayment  placeID_y        Rcuisine
# 0     135110                 cash     135110         Spanish
# 1     135110                 VISA     135109         Italian
# 2     135110  MasterCard-Eurocard     135107  Latin_American
# 3     135110     American_Express     135106         Mexican
# 4     135110     bank_debit_cards     135105       Fast_Food
